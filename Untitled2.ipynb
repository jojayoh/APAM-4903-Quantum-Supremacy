# %% [markdown]
# # Quantum Computing Demonstration
#
# Much of the ideas and structure of the code were adapted from the Qiskit Online Textbook on Shor's Algorithm
# https://qiskit.org/textbook/ch-algorithms/shor.html

# %%
import matplotlib.pyplot as plt
import numpy as np
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram
from qiskit.circuit.library import QFT
from math import gcd
from numpy.random import randint
import pandas as pd
from fractions import Fraction

# %%
#builds a quantum circuit which conditionally multiplies by 2^power mod 63
def c_2times_mod63(power):
    
    U = QuantumCircuit(6)
    
    #multiplication by 2 mod 63 is very simple logically, since the multiplication
    #can be separated into operations of each bit
    for i in range(power):
        U.swap(5,4)
        U.swap(4,3)
        U.swap(3,2)
        U.swap(2,1)
        U.swap(1,0)
    
    U = U.to_gate()
    U.name = "2^%i mod 63" % (power)
    
    #adds a control line to the gate
    c_U = U.control()
    
    return c_U

# %%
#17 qubits, 11 to hold x and 6 to hold f(x)
#11 classical bits to hold the measurement
qc = QuantumCircuit(17, 11)


#apply Hadamard gate to each of the qubits that represent x
#result is uniform superposition
for i in range(11):
    qc.h(i)

#the qubits that represent f(x) start in state 0, change the state
#to 1, so that we can simply multiply mod 63
qc.x(11)

#perform controlled multiplication by the values 2^(2^i) on the f(x) register
for i in range(11):
    qc.append(c_2times_mod63(2**i), [i] + [11 + j for j in range(6)])

#apply QFT to the qubits that represent x
qc.append(QFT(11, name='QFT'), [10 - i for i in range(11)])

#perform measurement of the first register
qc.measure(range(11), range(11))

qc.draw('text')
# Out:
#       ┌───┐                                                            »
#  q_0: ┤ H ├───────■────────────────────────────────────────────────────»
#       ├───┤       │                                                    »
#  q_1: ┤ H ├───────┼──────────────■─────────────────────────────────────»
#       ├───┤       │              │                                     »
#  q_2: ┤ H ├───────┼──────────────┼──────────────■──────────────────────»
#       ├───┤       │              │              │                      »
#  q_3: ┤ H ├───────┼──────────────┼──────────────┼──────────────■───────»
#       ├───┤       │              │              │              │       »
#  q_4: ┤ H ├───────┼──────────────┼──────────────┼──────────────┼───────»
#       ├───┤       │              │              │              │       »
#  q_5: ┤ H ├───────┼──────────────┼──────────────┼──────────────┼───────»
#       ├───┤       │              │              │              │       »
#  q_6: ┤ H ├───────┼──────────────┼──────────────┼──────────────┼───────»
#       ├───┤       │              │              │              │       »
#  q_7: ┤ H ├───────┼──────────────┼──────────────┼──────────────┼───────»
#       ├───┤       │              │              │              │       »
#  q_8: ┤ H ├───────┼──────────────┼──────────────┼──────────────┼───────»
#       ├───┤       │              │              │              │       »
#  q_9: ┤ H ├───────┼──────────────┼──────────────┼──────────────┼───────»
#       ├───┤       │              │              │              │       »
# q_10: ┤ H ├───────┼──────────────┼──────────────┼──────────────┼───────»
#       ├───┤┌──────┴──────┐┌──────┴──────┐┌──────┴──────┐┌──────┴──────┐»
# q_11: ┤ X ├┤0            ├┤0            ├┤0            ├┤0            ├»
#       └───┘│             ││             ││             ││             │»
# q_12: ─────┤1            ├┤1            ├┤1            ├┤1            ├»
#            │             ││             ││             ││             │»
# q_13: ─────┤2            ├┤2            ├┤2            ├┤2            ├»
#            │  2^1 mod 63 ││  2^2 mod 63 ││  2^4 mod 63 ││  2^8 mod 63 │»
# q_14: ─────┤3            ├┤3            ├┤3            ├┤3            ├»
#            │             ││             ││             ││             │»
# q_15: ─────┤4            ├┤4            ├┤4            ├┤4            ├»
#            │             ││             ││             ││             │»
# q_16: ─────┤5            ├┤5            ├┤5            ├┤5            ├»
#            └─────────────┘└─────────────┘└─────────────┘└─────────────┘»
# c: 11/═════════════════════════════════════════════════════════════════»
#                                                                        »
# «                                                                       »
# « q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_1: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_2: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_3: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_4: ───────■─────────────────────────────────────────────────────────»
# «             │                                                         »
# « q_5: ───────┼───────────────■─────────────────────────────────────────»
# «             │               │                                         »
# « q_6: ───────┼───────────────┼───────────────■─────────────────────────»
# «             │               │               │                         »
# « q_7: ───────┼───────────────┼───────────────┼────────────────■────────»
# «             │               │               │                │        »
# « q_8: ───────┼───────────────┼───────────────┼────────────────┼────────»
# «             │               │               │                │        »
# « q_9: ───────┼───────────────┼───────────────┼────────────────┼────────»
# «             │               │               │                │        »
# «q_10: ───────┼───────────────┼───────────────┼────────────────┼────────»
# «      ┌──────┴───────┐┌──────┴───────┐┌──────┴───────┐┌───────┴───────┐»
# «q_11: ┤0             ├┤0             ├┤0             ├┤0              ├»
# «      │              ││              ││              ││               │»
# «q_12: ┤1             ├┤1             ├┤1             ├┤1              ├»
# «      │              ││              ││              ││               │»
# «q_13: ┤2             ├┤2             ├┤2             ├┤2              ├»
# «      │  2^16 mod 63 ││  2^32 mod 63 ││  2^64 mod 63 ││  2^128 mod 63 │»
# «q_14: ┤3             ├┤3             ├┤3             ├┤3              ├»
# «      │              ││              ││              ││               │»
# «q_15: ┤4             ├┤4             ├┤4             ├┤4              ├»
# «      │              ││              ││              ││               │»
# «q_16: ┤5             ├┤5             ├┤5             ├┤5              ├»
# «      └──────────────┘└──────────────┘└──────────────┘└───────────────┘»
# «c: 11/═════════════════════════════════════════════════════════════════»
# «                                                                       »
# «                                                          ┌───────┐┌─┐      »
# « q_0: ────────────────────────────────────────────────────┤10     ├┤M├──────»
# «                                                          │       │└╥┘┌─┐   »
# « q_1: ────────────────────────────────────────────────────┤9      ├─╫─┤M├───»
# «                                                          │       │ ║ └╥┘┌─┐»
# « q_2: ────────────────────────────────────────────────────┤8      ├─╫──╫─┤M├»
# «                                                          │       │ ║  ║ └╥┘»
# « q_3: ────────────────────────────────────────────────────┤7      ├─╫──╫──╫─»
# «                                                          │       │ ║  ║  ║ »
# « q_4: ────────────────────────────────────────────────────┤6      ├─╫──╫──╫─»
# «                                                          │       │ ║  ║  ║ »
# « q_5: ────────────────────────────────────────────────────┤5  QFT ├─╫──╫──╫─»
# «                                                          │       │ ║  ║  ║ »
# « q_6: ────────────────────────────────────────────────────┤4      ├─╫──╫──╫─»
# «                                                          │       │ ║  ║  ║ »
# « q_7: ────────────────────────────────────────────────────┤3      ├─╫──╫──╫─»
# «                                                          │       │ ║  ║  ║ »
# « q_8: ────────■───────────────────────────────────────────┤2      ├─╫──╫──╫─»
# «              │                                           │       │ ║  ║  ║ »
# « q_9: ────────┼────────────────■──────────────────────────┤1      ├─╫──╫──╫─»
# «              │                │                          │       │ ║  ║  ║ »
# «q_10: ────────┼────────────────┼────────────────■─────────┤0      ├─╫──╫──╫─»
# «      ┌───────┴───────┐┌───────┴───────┐┌───────┴────────┐└───────┘ ║  ║  ║ »
# «q_11: ┤0              ├┤0              ├┤0               ├──────────╫──╫──╫─»
# «      │               ││               ││                │          ║  ║  ║ »
# «q_12: ┤1              ├┤1              ├┤1               ├──────────╫──╫──╫─»
# «      │               ││               ││                │          ║  ║  ║ »
# «q_13: ┤2              ├┤2              ├┤2               ├──────────╫──╫──╫─»
# «      │  2^256 mod 63 ││  2^512 mod 63 ││  2^1024 mod 63 │          ║  ║  ║ »
# «q_14: ┤3              ├┤3              ├┤3               ├──────────╫──╫──╫─»
# «      │               ││               ││                │          ║  ║  ║ »
# «q_15: ┤4              ├┤4              ├┤4               ├──────────╫──╫──╫─»
# «      │               ││               ││                │          ║  ║  ║ »
# «q_16: ┤5              ├┤5              ├┤5               ├──────────╫──╫──╫─»
# «      └───────────────┘└───────────────┘└────────────────┘          ║  ║  ║ »
# «c: 11/══════════════════════════════════════════════════════════════╩══╩══╩═»
# «                                                                    0  1  2 »
# «
# « q_0: ────────────────────────
# «
# « q_1: ────────────────────────
# «
# « q_2: ────────────────────────
# «      ┌─┐
# « q_3: ┤M├─────────────────────
# «      └╥┘┌─┐
# « q_4: ─╫─┤M├──────────────────
# «       ║ └╥┘┌─┐
# « q_5: ─╫──╫─┤M├───────────────
# «       ║  ║ └╥┘┌─┐
# « q_6: ─╫──╫──╫─┤M├────────────
# «       ║  ║  ║ └╥┘┌─┐
# « q_7: ─╫──╫──╫──╫─┤M├─────────
# «       ║  ║  ║  ║ └╥┘┌─┐
# « q_8: ─╫──╫──╫──╫──╫─┤M├──────
# «       ║  ║  ║  ║  ║ └╥┘┌─┐
# « q_9: ─╫──╫──╫──╫──╫──╫─┤M├───
# «       ║  ║  ║  ║  ║  ║ └╥┘┌─┐
# «q_10: ─╫──╫──╫──╫──╫──╫──╫─┤M├
# «       ║  ║  ║  ║  ║  ║  ║ └╥┘
# «q_11: ─╫──╫──╫──╫──╫──╫──╫──╫─
# «       ║  ║  ║  ║  ║  ║  ║  ║
# «q_12: ─╫──╫──╫──╫──╫──╫──╫──╫─
# «       ║  ║  ║  ║  ║  ║  ║  ║
# «q_13: ─╫──╫──╫──╫──╫──╫──╫──╫─
# «       ║  ║  ║  ║  ║  ║  ║  ║
# «q_14: ─╫──╫──╫──╫──╫──╫──╫──╫─
# «       ║  ║  ║  ║  ║  ║  ║  ║
# «q_15: ─╫──╫──╫──╫──╫──╫──╫──╫─
# «       ║  ║  ║  ║  ║  ║  ║  ║
# «q_16: ─╫──╫──╫──╫──╫──╫──╫──╫─
# «       ║  ║  ║  ║  ║  ║  ║  ║
# «c: 11/═╩══╩══╩══╩══╩══╩══╩══╩═
# «       3  4  5  6  7  8  9  10

# %%
#use a backend that simulates quantum computer on classical computer
#provided by IBM
backend = Aer.get_backend('qasm_simulator')

#perform the calculation 5000 times
results = execute(qc, backend, shots=5000).result()
counts = results.get_counts()
plot_histogram(counts, ax = plt.axes())
plt.show()

# %%
print(counts)
counts_more_than10 = {int(k,2)/(2**11):v for (k,v) in counts.items() if v > 20}
plot_histogram(counts_more_than10, bar_labels=False)
# Out:
# {'00000000000': 792, '00100011100': 1, '00100110111': 1, '00100111011': 1, '00100111101': 1, '00100111110': 1, '00101001000': 1, '00101001001': 3, '00101001010': 1, '00101001011': 2, '00101001101': 3, '00101001110': 2, '00101001111': 2, '00101010000': 3, '00101010001': 3, '00101010010': 3, '00101010011': 14, '00101010100': 42, '00101010101': 587, '00101010110': 154, '00101010111': 28, '00101011000': 9, '00101011001': 8, '00101011010': 1, '00101011011': 7, '00101011100': 1, '00101011101': 1, '00101100001': 2, '00101100100': 1, '00101100101': 1, '00101101001': 1, '00101101111': 1, '00101110000': 1, '00110101101': 1, '01001010000': 1, '01010000110': 1, '01010010000': 1, '01010011010': 1, '01010011101': 1, '01010011111': 3, '01010100000': 1, '01010100010': 1, '01010100011': 2, '01010100100': 1, '01010100101': 1, '01010100110': 2, '01010100111': 5, '01010101000': 9, '01010101001': 17, '01010101010': 162, '01010101011': 528, '01010101100': 29, '01010101101': 8, '01010101110': 6, '01010101111': 1, '01010110000': 4, '01010110001': 6, '01010110010': 2, '01010110011': 2, '01010110100': 1, '01010111000': 2, '01011001000': 1, '01011001001': 1, '01100000000': 1, '01100101110': 1, '10000000000': 836, '10001010110': 1, '10011111111': 1, '10100110100': 1, '10100111110': 1, '10101000111': 1, '10101001011': 1, '10101001101': 1, '10101001110': 2, '10101010000': 2, '10101010001': 4, '10101010010': 6, '10101010011': 16, '10101010100': 28, '10101010101': 600, '10101010110': 151, '10101010111': 30, '10101011000': 10, '10101011001': 8, '10101011010': 4, '10101011011': 5, '10101011100': 1, '10101100001': 1, '10101100111': 1, '10101101100': 1, '10110001101': 1, '10110110101': 1, '11000001110': 1, '11001111111': 1, '11010001101': 1, '11010011010': 1, '11010100001': 3, '11010100100': 1, '11010100101': 2, '11010100110': 2, '11010100111': 3, '11010101000': 7, '11010101001': 24, '11010101010': 140, '11010101011': 540, '11010101100': 39, '11010101101': 7, '11010101110': 3, '11010101111': 7, '11010110000': 3, '11010110001': 1, '11010110010': 3, '11010110011': 1, '11010110110': 2, '11010111010': 1, '11010111100': 1, '11011000000': 1, '11011001010': 1, '11011011010': 1, '11011100001': 1, '11011101110': 1, '11100010011': 1, '11111011101': 1, '00010101101': 1, '00010111110': 1}

# %%
print(2**11)
# Out:
# 2048
